# %% [markdown]
# # Lab 4 — Registry explorer (optional)
#
# After running **`list_models.py`** or the full script path, you can call the same boto3 APIs from here to explore **Model Package Groups** and approvals.

# %%
from pathlib import Path
import sys

SCRIPT = Path.cwd().resolve().parent / "scripts"
sys.path.insert(0, str(SCRIPT))

import list_models

list_models.list_model_groups()
