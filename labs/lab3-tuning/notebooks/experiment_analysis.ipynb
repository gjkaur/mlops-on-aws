# %% [markdown]
# # Lab 3 · Experiment analysis (optional)
#
# After completing the scripted flow in `scripts/`, you can reuse `analyze_results.py` helpers from this notebook.

# %%
from pathlib import Path
import sys

SCRIPT = Path.cwd().resolve().parent / "scripts"
sys.path.insert(0, str(SCRIPT))

from analyze_results import get_tuning_results, print_best_models

JOB = (SCRIPT / "tuning_job_name.txt").read_text().strip()
df = get_tuning_results(JOB)
df.head()
print_best_models(df)
